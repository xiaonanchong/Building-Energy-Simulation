# %%
# !pip install git+https://github.com/openai/baselines > ~/pip_install_baselines.log
# !OPENAI_LOGDIR=$HOME/logs/mountain_car_trpo OPENAI_LOG_FORMAT=csv
# Out:
# You are using pip version 8.1.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !python -m baselines.run --alg=trpo_mpi --env='MountainCarContinuous-v0' --num_timesteps=1e4  #'gym_energyplus:EnergyPlus-v0'
# Out:
# /home/hchonglondon/.local/lib/python3.5/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)
# Logging to /tmp/openai-2019-05-25-17-52-57-620748
# env_type: classic_control
# 2019-05-25 17:52:57.643651: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-05-25 17:52:57.649537: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-05-25 17:52:57.650874: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x52d80f0 executing computations on platform Host. Devices:
# 2019-05-25 17:52:57.650950: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# Training trpo_mpi on classic_control:MountainCarContinuous-v0 with arguments
# {'network': 'mlp'}
# WARNING:tensorflow:From /home/hchonglondon/baselines/baselines/common/input.py:57: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/hchonglondon/baselines/baselines/common/models.py:94: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/hchonglondon/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/hchonglondon/.local/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Init param sum 16.737593
# ********** Iteration 0 ************
# sampling
# done in 0.850 seconds
# computegrad
# done in 0.049 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000626          0
#          1   0.000137      0.015
#          2   0.000175      0.107
#          3   1.48e-07      0.116
#          4   4.29e-11      0.123
# done in 0.092 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.164 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.41     |
# | EpisodesSoFar   | 1        |
# | EpLenMean       | 999      |
# | EpRewMean       | -51.1    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.00504  |
# | meankl          | 0.000919 |
# | optimgain       | 0.00177  |
# | surrgain        | 0.00177  |
# | TimeElapsed     | 1.23     |
# | TimestepsSoFar  | 999      |
# ------------------------------
# ********** Iteration 1 ************
# sampling
# done in 0.827 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00398          0
#          1   4.18e-05     0.0296
#          2   0.000459      0.111
#          3   4.21e-06      0.165
#          4   2.91e-11      0.278
# done in 0.013 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.088 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.4      |
# | EpisodesSoFar   | 2        |
# | EpLenMean       | 999      |
# | EpRewMean       | -51.2    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.031    |
# | meankl          | 0.000814 |
# | optimgain       | 0.0026   |
# | surrgain        | 0.0026   |
# | TimeElapsed     | 2.18     |
# | TimestepsSoFar  | 2e+03    |
# ------------------------------
# ********** Iteration 2 ************
# sampling
# done in 0.830 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00382          0
#          1   9.34e-05     0.0254
#          2   0.000115       0.03
#          3   1.72e-08     0.0502
#          4   5.12e-11      0.052
# done in 0.013 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.087 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.42     |
# | EpisodesSoFar   | 3        |
# | EpLenMean       | 999      |
# | EpRewMean       | -51.1    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.33    |
# | meankl          | 0.000973 |
# | optimgain       | 0.00199  |
# | surrgain        | 0.00199  |
# | TimeElapsed     | 3.13     |
# | TimestepsSoFar  | 3e+03    |
# ------------------------------
# ********** Iteration 3 ************
# sampling
# done in 0.827 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00486          0
#          1   2.73e-06     0.0346
#          2    8.4e-08     0.0346
#          3   1.71e-07     0.0361
#          4   2.77e-10     0.0423
#          5   1.25e-08     0.0424
#          6   2.19e-10     0.0424
#          7   9.91e-17     0.0424
# done in 0.024 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.089 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.39     |
# | EpisodesSoFar   | 4        |
# | EpLenMean       | 999      |
# | EpRewMean       | -51.6    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.332   |
# | meankl          | 0.00101  |
# | optimgain       | 0.00219  |
# | surrgain        | 0.00219  |
# | TimeElapsed     | 4.09     |
# | TimestepsSoFar  | 4e+03    |
# ------------------------------
# ********** Iteration 4 ************
# sampling
# done in 0.833 seconds
# computegrad
# done in 0.005 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00646          0
#          1   9.76e-05     0.0359
#          2   2.96e-06     0.0367
#          3   6.05e-06     0.0443
#          4   6.25e-09      0.124
#          5   2.42e-07      0.125
#          6   5.35e-09      0.125
#          7   5.61e-13      0.125
# done in 0.023 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.41     |
# | EpisodesSoFar   | 5        |
# | EpLenMean       | 999      |
# | EpRewMean       | -51.2    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -1.56    |
# | meankl          | 0.000928 |
# | optimgain       | 0.00248  |
# | surrgain        | 0.00248  |
# | TimeElapsed     | 5.06     |
# | TimestepsSoFar  | 5e+03    |
# ------------------------------
# ********** Iteration 5 ************
# sampling
# done in 0.862 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00212          0
#          1   2.65e-05     0.0211
#          2   3.31e-05     0.0225
#          3   4.35e-09      0.048
#          4   1.68e-11     0.0485
# done in 0.014 seconds
# Expected: 0.002 Actual: 0.001
# Stepsize OK!
# vf
# done in 0.095 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.39     |
# | EpisodesSoFar   | 6        |
# | EpLenMean       | 999      |
# | EpRewMean       | -51.3    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.337   |
# | meankl          | 0.00101  |
# | optimgain       | 0.0015   |
# | surrgain        | 0.0015   |
# | TimeElapsed     | 6.06     |
# | TimestepsSoFar  | 5.99e+03 |
# ------------------------------
# ********** Iteration 6 ************
# sampling
# done in 0.835 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0136          0
#          1   0.000136     0.0583
#          2    0.00128     0.0891
#          3   2.44e-09      0.418
#          4   1.32e-10      0.418
#          5   5.07e-13      0.418
# done in 0.017 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.090 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.37     |
# | EpisodesSoFar   | 7        |
# | EpLenMean       | 999      |
# | EpRewMean       | -51.3    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0572  |
# | meankl          | 0.000842 |
# | optimgain       | 0.00464  |
# | surrgain        | 0.00464  |
# | TimeElapsed     | 7.02     |
# | TimestepsSoFar  | 6.99e+03 |
# ------------------------------
# ********** Iteration 7 ************
# sampling
# done in 0.798 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0216          0
#          1     0.0011      0.074
#          2    0.00256      0.103
#          3   1.43e-06      0.203
#          4   1.72e-09       0.23
#          5   4.75e-08       0.23
#          6   5.16e-12       0.23
# done in 0.020 seconds
# Expected: 0.006 Actual: 0.006
# Stepsize OK!
# vf
# done in 0.089 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.34     |
# | EpisodesSoFar   | 8        |
# | EpLenMean       | 999      |
# | EpRewMean       | -51.5    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.499   |
# | meankl          | 0.000993 |
# | optimgain       | 0.00552  |
# | surrgain        | 0.00552  |
# | TimeElapsed     | 7.95     |
# | TimestepsSoFar  | 7.99e+03 |
# ------------------------------
# ********** Iteration 8 ************
# sampling
# done in 0.832 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0147          0
#          1   1.58e-06     0.0604
#          2   2.64e-05      0.118
#          3   7.66e-08      0.126
#          4   3.81e-09      0.126
#          5   1.72e-07      0.126
#          6   1.19e-14      0.127
# done in 0.020 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.086 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.31     |
# | EpisodesSoFar   | 9        |
# | EpLenMean       | 999      |
# | EpRewMean       | -51.4    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.296   |
# | meankl          | 0.000999 |
# | optimgain       | 0.00383  |
# | surrgain        | 0.00383  |
# | TimeElapsed     | 8.91     |
# | TimestepsSoFar  | 8.99e+03 |
# ------------------------------
# ********** Iteration 9 ************
# sampling
# done in 0.832 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00243          0
#          1   7.18e-05     0.0198
#          2   0.000194     0.0276
#          3   3.47e-07      0.199
#          4   4.43e-10      0.212
#          5   5.88e-11      0.212
# done in 0.016 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.073 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.3      |
# | EpisodesSoFar   | 10       |
# | EpLenMean       | 999      |
# | EpRewMean       | -50.9    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0324  |
# | meankl          | 0.000937 |
# | optimgain       | 0.00228  |
# | surrgain        | 0.00228  |
# | TimeElapsed     | 9.85     |
# | TimestepsSoFar  | 9.99e+03 |
# ------------------------------
# ********** Iteration 10 ************
# sampling
# done in 0.862 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00262          0
#          1   6.07e-05       0.02
#          2   7.04e-06      0.021
#          3   1.75e-06     0.0618
#          4   5.71e-10       0.14
#          5   2.62e-11       0.14
# done in 0.017 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.092 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.29     |
# | EpisodesSoFar   | 11       |
# | EpLenMean       | 999      |
# | EpRewMean       | -50.6    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.161   |
# | meankl          | 0.000833 |
# | optimgain       | 0.00156  |
# | surrgain        | 0.00156  |
# | TimeElapsed     | 10.8     |
# | TimestepsSoFar  | 1.1e+04  |
# ------------------------------

# %%
from baselines.common import plot_util as pu
results = pu.load_results('~/logs/cartpole-ppo')


import matplotlib.pyplot as plt
import numpy as np
r = results[0]
plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-5552d4999a6e> in <module>()
#       1 from baselines.common import plot_util as pu
# ----> 2 results = pu.load_results('~/logs/cartpole-ppo')
#       3
#       4
#       5 import matplotlib.pyplot as plt
#
# /home/hchonglondon/baselines/baselines/common/plot_util.py in load_results(root_dir_or_dirs, enable_progress, enable_monitor, verbose)
#     176     allresults = []
#     177     for rootdir in rootdirs:
# --> 178         assert osp.exists(rootdir), "%s doesn't exist"%rootdir
#     179         for dirname, dirs, files in os.walk(rootdir):
#     180             if '-proc' in dirname:
#
# AssertionError: /home/hchonglondon/logs/cartpole-ppo doesn't exist

# %%
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

# %%
plt.plot(r.progress.total_timesteps, r.progress.eprewmean)
