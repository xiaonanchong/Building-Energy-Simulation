# %%
# !pip install git+https://github.com/openai/baselines > ~/pip_install_baselines.log
# Out:
# You are using pip version 8.1.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !OPENAI_LOGDIR=$HOME/logs/cartpole-ppo OPENAI_LOG_FORMAT=csv

# %%
# !python -m baselines.run --alg=trpo_mpi --env='MountainCarContinuous-v0' --num_timesteps=10
# Out:
# /home/hchonglondon/.local/lib/python3.5/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)
# Logging to /tmp/openai-2019-05-25-16-45-45-951025
# env_type: classic_control
# 2019-05-25 16:45:45.977609: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-05-25 16:45:45.983915: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-05-25 16:45:45.985719: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x4254c50 executing computations on platform Host. Devices:
# 2019-05-25 16:45:45.985782: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# Training trpo_mpi on classic_control:MountainCarContinuous-v0 with arguments
# {'network': 'mlp'}
# WARNING:tensorflow:From /home/hchonglondon/baselines/baselines/common/input.py:57: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/hchonglondon/baselines/baselines/common/models.py:94: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/hchonglondon/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/hchonglondon/.local/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Init param sum 15.630799
# ********** Iteration 0 ************
# sampling
# done in 1.137 seconds
# computegrad
# done in 0.292 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00143          0
#          1   1.51e-05      0.019
#          2    2.1e-05     0.0399
#          3   8.38e-07     0.0425
#          4   1.01e-10     0.0945
#          5   4.91e-09     0.0945
#          6   2.71e-12     0.0945
# done in 0.106 seconds
# Expected: 0.001 Actual: 0.001
# Stepsize OK!
# vf
# done in 0.170 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.39     |
# | EpisodesSoFar   | 1        |
# | EpLenMean       | 999      |
# | EpRewMean       | -49.6    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.00563 |
# | meankl          | 0.000927 |
# | optimgain       | 0.00134  |
# | surrgain        | 0.00134  |
# | TimeElapsed     | 1.78     |
# | TimestepsSoFar  | 999      |
# ------------------------------
# ********** Iteration 1 ************
# sampling
# done in 0.849 seconds
# computegrad
# done in 0.005 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00966          0
#          1   5.09e-05     0.0485
#          2   0.000117     0.0505
#          3   7.74e-09      0.149
#          4    2.1e-10      0.149
#          5   1.77e-12      0.149
# done in 0.017 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.091 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.36     |
# | EpisodesSoFar   | 2        |
# | EpLenMean       | 999      |
# | EpRewMean       | -50      |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0135  |
# | meankl          | 0.000982 |
# | optimgain       | 0.00329  |
# | surrgain        | 0.00329  |
# | TimeElapsed     | 2.76     |
# | TimestepsSoFar  | 2e+03    |
# ------------------------------
# ********** Iteration 2 ************
# sampling
# done in 0.851 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0088          0
#          1   4.82e-05     0.0454
#          2   5.32e-07     0.0457
#          3   1.49e-08     0.0475
#          4   6.37e-11     0.0493
# done in 0.014 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.085 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.33     |
# | EpisodesSoFar   | 3        |
# | EpLenMean       | 999      |
# | EpRewMean       | -49.9    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0841  |
# | meankl          | 0.00102  |
# | optimgain       | 0.00295  |
# | surrgain        | 0.00295  |
# | TimeElapsed     | 3.73     |
# | TimestepsSoFar  | 3e+03    |
# ------------------------------
# ********** Iteration 3 ************
# sampling
# done in 0.878 seconds
# computegrad
# done in 0.005 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000324          0
#          1   5.93e-05    0.00796
#          2   1.67e-05     0.0351
#          3   1.22e-06     0.0365
#          4   3.47e-10     0.0954
#          5   1.47e-08     0.0955
#          6   1.09e-13     0.0955
# done in 0.024 seconds
# Expected: 0.001 Actual: 0.001
# Stepsize OK!
# vf
# done in 0.095 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.33     |
# | EpisodesSoFar   | 4        |
# | EpLenMean       | 999      |
# | EpRewMean       | -49.2    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -1.21    |
# | meankl          | 0.000801 |
# | optimgain       | 0.000867 |
# | surrgain        | 0.000867 |
# | TimeElapsed     | 4.75     |
# | TimestepsSoFar  | 4e+03    |
# ------------------------------
# ********** Iteration 4 ************
# sampling
# done in 0.826 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0018          0
#          1    2.9e-05     0.0195
#          2   1.53e-06     0.0199
#          3   1.32e-06     0.0444
#          4   1.03e-09     0.0958
#          5   4.66e-08     0.0958
#          6   8.16e-09     0.0959
#          7   4.91e-17     0.0959
# done in 0.021 seconds
# Expected: 0.001 Actual: 0.001
# Stepsize OK!
# vf
# done in 0.083 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.31     |
# | EpisodesSoFar   | 5        |
# | EpLenMean       | 999      |
# | EpRewMean       | -49.2    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.332   |
# | meankl          | 0.000951 |
# | optimgain       | 0.00146  |
# | surrgain        | 0.00146  |
# | TimeElapsed     | 5.71     |
# | TimestepsSoFar  | 5e+03    |
# ------------------------------
# ********** Iteration 5 ************
# sampling
# done in 0.830 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00318          0
#          1   2.52e-05     0.0207
#          2   7.74e-05      0.102
#          3   1.07e-08       0.11
#          4   2.84e-10      0.111
#          5   2.86e-12      0.111
# done in 0.017 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.086 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.31     |
# | EpisodesSoFar   | 6        |
# | EpLenMean       | 999      |
# | EpRewMean       | -48.6    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.178   |
# | meankl          | 0.000875 |
# | optimgain       | 0.00196  |
# | surrgain        | 0.00196  |
# | TimeElapsed     | 6.66     |
# | TimestepsSoFar  | 5.99e+03 |
# ------------------------------
# ********** Iteration 6 ************
# sampling
# done in 0.792 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00274          0
#          1   6.87e-05     0.0208
#          2   7.44e-06     0.0218
#          3   1.18e-07     0.0721
#          4   9.77e-11     0.0828
# done in 0.013 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.081 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.29     |
# | EpisodesSoFar   | 7        |
# | EpLenMean       | 999      |
# | EpRewMean       | -48.1    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.162   |
# | meankl          | 0.00105  |
# | optimgain       | 0.00165  |
# | surrgain        | 0.00165  |
# | TimeElapsed     | 7.57     |
# | TimestepsSoFar  | 6.99e+03 |
# ------------------------------
# ********** Iteration 7 ************
# sampling
# done in 0.830 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00524          0
#          1   0.000308     0.0353
#          2   0.000368     0.0413
#          3   1.36e-06      0.126
#          4   1.94e-09      0.169
#          5   1.09e-07      0.169
#          6   9.72e-09      0.169
#          7   5.63e-15      0.169
# done in 0.022 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.088 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.26     |
# | EpisodesSoFar   | 8        |
# | EpLenMean       | 999      |
# | EpRewMean       | -47.8    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.438   |
# | meankl          | 0.000973 |
# | optimgain       | 0.00288  |
# | surrgain        | 0.00288  |
# | TimeElapsed     | 8.53     |
# | TimestepsSoFar  | 7.99e+03 |
# ------------------------------
# ********** Iteration 8 ************
# sampling
# done in 0.834 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00139          0
#          1   8.77e-05     0.0132
#          2   0.000267     0.0282
#          3   3.38e-07      0.113
#          4   3.41e-10      0.128
#          5   6.88e-09      0.128
#          6   6.52e-10      0.128
#          7   6.95e-16      0.128
# done in 0.021 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.087 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.27     |
# | EpisodesSoFar   | 9        |
# | EpLenMean       | 999      |
# | EpRewMean       | -47.6    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.477   |
# | meankl          | 0.000763 |
# | optimgain       | 0.00157  |
# | surrgain        | 0.00157  |
# | TimeElapsed     | 9.5      |
# | TimestepsSoFar  | 8.99e+03 |
# ------------------------------
# ********** Iteration 9 ************
# sampling
# done in 0.796 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0343          0
#          1    0.00114     0.0647
#          2    0.00146     0.0827
#          3   2.62e-06       0.24
#          4   9.81e-09      0.291
#          5   5.47e-07      0.291
#          6   2.47e-08      0.292
#          7   1.02e-13      0.292
# done in 0.020 seconds
# Expected: 0.006 Actual: 0.006
# Stepsize OK!
# vf
# done in 0.084 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.26     |
# | EpisodesSoFar   | 10       |
# | EpLenMean       | 999      |
# | EpRewMean       | -47.3    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.866   |
# | meankl          | 0.001    |
# | optimgain       | 0.0061   |
# | surrgain        | 0.0061   |
# | TimeElapsed     | 10.4     |
# | TimestepsSoFar  | 9.99e+03 |
# ------------------------------
# ********** Iteration 10 ************
# sampling
# done in 0.835 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0103          0
#          1   3.84e-06     0.0346
#          2   7.18e-08     0.0346
#          3   9.57e-09     0.0359
#          4   1.23e-09     0.0377
#          5      1e-12     0.0377
# done in 0.016 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.086 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.26     |
# | EpisodesSoFar   | 11       |
# | EpLenMean       | 999      |
# | EpRewMean       | -47      |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0575  |
# | meankl          | 0.001    |
# | optimgain       | 0.00264  |
# | surrgain        | 0.00264  |
# | TimeElapsed     | 11.4     |
# | TimestepsSoFar  | 1.1e+04  |
# ------------------------------
# ********** Iteration 11 ************
# sampling
# done in 0.823 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00167          0
#          1    0.00979      0.176
#          2   2.23e-06      0.345
#          3   1.17e-06      0.345
#          4   1.69e-09      0.356
#          5    9.8e-08      0.356
#          6   8.13e-13      0.356
# done in 0.021 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.092 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.26     |
# | EpisodesSoFar   | 12       |
# | EpLenMean       | 999      |
# | EpRewMean       | -46.7    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.233   |
# | meankl          | 0.000904 |
# | optimgain       | 0.00515  |
# | surrgain        | 0.00515  |
# | TimeElapsed     | 12.3     |
# | TimestepsSoFar  | 1.2e+04  |
# ------------------------------
# ********** Iteration 12 ************
# sampling
# done in 0.836 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00104          0
#          1   0.000367     0.0185
#          2    0.00101     0.0531
#          3   9.42e-07      0.137
#          4   2.07e-10      0.165
#          5   9.44e-09      0.165
#          6   2.87e-09      0.165
#          7   6.96e-14      0.165
# done in 0.023 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.091 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.27     |
# | EpisodesSoFar   | 13       |
# | EpLenMean       | 999      |
# | EpRewMean       | -46.5    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.534   |
# | meankl          | 0.000899 |
# | optimgain       | 0.00234  |
# | surrgain        | 0.00234  |
# | TimeElapsed     | 13.3     |
# | TimestepsSoFar  | 1.3e+04  |
# ------------------------------
# ********** Iteration 13 ************
# sampling
# done in 0.845 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00406          0
#          1   7.98e-05     0.0226
#          2   5.01e-07     0.0236
#          3    6.6e-07     0.0342
#          4    7.2e-10     0.0641
#          5   1.79e-08     0.0642
#          6    1.9e-08     0.0642
#          7   1.28e-15     0.0643
# done in 0.027 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.077 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.28     |
# | EpisodesSoFar   | 14       |
# | EpLenMean       | 999      |
# | EpRewMean       | -46.4    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.305   |
# | meankl          | 0.000973 |
# | optimgain       | 0.00174  |
# | surrgain        | 0.00174  |
# | TimeElapsed     | 14.3     |
# | TimestepsSoFar  | 1.4e+04  |
# ------------------------------
# ********** Iteration 14 ************
# sampling
# done in 0.817 seconds
# computegrad
# done in 0.005 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00509          0
#          1    0.00306     0.0459
#          2    0.00142      0.146
#          3   3.68e-06      0.165
#          4   8.05e-10      0.225
#          5   4.06e-08      0.225
#          6   5.63e-13      0.225
# done in 0.019 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.092 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.28     |
# | EpisodesSoFar   | 15       |
# | EpLenMean       | 999      |
# | EpRewMean       | -46.5    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.859   |
# | meankl          | 0.000932 |
# | optimgain       | 0.00419  |
# | surrgain        | 0.00419  |
# | TimeElapsed     | 15.2     |
# | TimestepsSoFar  | 1.5e+04  |
# ------------------------------
# ********** Iteration 15 ************
# sampling
# done in 0.871 seconds
# computegrad
# done in 0.005 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00469          0
#          1   0.000157     0.0284
#          2   2.95e-05     0.0303
#          3   6.68e-08     0.0965
#          4   1.24e-10      0.101
#          5   3.41e-12      0.101
# done in 0.017 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.090 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.26     |
# | EpisodesSoFar   | 16       |
# | EpLenMean       | 999      |
# | EpRewMean       | -46.4    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.169   |
# | meankl          | 0.00101  |
# | optimgain       | 0.00222  |
# | surrgain        | 0.00222  |
# | TimeElapsed     | 16.2     |
# | TimestepsSoFar  | 1.6e+04  |
# ------------------------------
# ********** Iteration 16 ************
# sampling
# done in 0.830 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00219          0
#          1    0.00128     0.0305
#          2    0.00372      0.137
#          3   1.01e-06      0.263
#          4   3.58e-09      0.283
#          5   1.03e-07      0.283
#          6   1.94e-09      0.283
#          7   1.17e-14      0.283
# done in 0.023 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.086 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.25     |
# | EpisodesSoFar   | 17       |
# | EpLenMean       | 999      |
# | EpRewMean       | -46.3    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.117   |
# | meankl          | 0.000907 |
# | optimgain       | 0.00403  |
# | surrgain        | 0.00403  |
# | TimeElapsed     | 17.2     |
# | TimestepsSoFar  | 1.7e+04  |
# ------------------------------
# ********** Iteration 17 ************
# sampling
# done in 0.838 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0      0.007          0
#          1    0.00236     0.0497
#          2    0.00327      0.113
#          3   2.06e-07      0.173
#          4   7.95e-10      0.179
#          5    1.6e-08      0.179
#          6   7.73e-09      0.179
#          7   3.75e-12      0.179
# done in 0.023 seconds
# Expected: 0.004 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.089 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.24     |
# | EpisodesSoFar   | 18       |
# | EpLenMean       | 999      |
# | EpRewMean       | -46.3    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.33    |
# | meankl          | 0.000986 |
# | optimgain       | 0.00451  |
# | surrgain        | 0.00451  |
# | TimeElapsed     | 18.2     |
# | TimestepsSoFar  | 1.8e+04  |
# ------------------------------
# ********** Iteration 18 ************
# sampling
# done in 0.838 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000311          0
#          1   2.84e-06    0.00885
#          2   6.99e-05     0.0232
#          3   9.85e-09     0.0655
#          4   3.58e-11     0.0667
# done in 0.014 seconds
# Expected: 0.001 Actual: 0.001
# Stepsize OK!
# vf
# done in 0.091 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.21     |
# | EpisodesSoFar   | 19       |
# | EpLenMean       | 999      |
# | EpRewMean       | -46      |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0414  |
# | meankl          | 0.000855 |
# | optimgain       | 0.000683 |
# | surrgain        | 0.000683 |
# | TimeElapsed     | 19.1     |
# | TimestepsSoFar  | 1.9e+04  |
# ------------------------------
# ********** Iteration 19 ************
# sampling
# done in 0.869 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00437          0
#          1   1.26e-06     0.0329
#          2   2.09e-06     0.0329
#          3    1.5e-07     0.0349
#          4   3.22e-10     0.0501
#          5   1.05e-08     0.0502
#          6   1.58e-10     0.0502
#          7   2.56e-15     0.0502
# done in 0.024 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.090 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.24     |
# | EpisodesSoFar   | 20       |
# | EpLenMean       | 999      |
# | EpRewMean       | -45.9    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0895  |
# | meankl          | 0.000968 |
# | optimgain       | 0.0024   |
# | surrgain        | 0.0024   |
# | TimeElapsed     | 20.1     |
# | TimestepsSoFar  | 2e+04    |
# ------------------------------
# ********** Iteration 20 ************
# sampling
# done in 0.837 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00401          0
#          1   0.000172     0.0301
#          2   7.58e-05     0.0322
#          3   2.17e-05     0.0536
#          4   8.35e-08      0.335
#          5   1.75e-07      0.338
#          6    1.8e-09      0.338
#          7   3.12e-12      0.338
# done in 0.024 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.087 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.22     |
# | EpisodesSoFar   | 21       |
# | EpLenMean       | 999      |
# | EpRewMean       | -45.7    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.26    |
# | meankl          | 0.000671 |
# | optimgain       | 0.00261  |
# | surrgain        | 0.00261  |
# | TimeElapsed     | 21.1     |
# | TimestepsSoFar  | 2.1e+04  |
# ------------------------------
# ********** Iteration 21 ************
# sampling
# done in 0.819 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00161          0
#          1   4.31e-06       0.02
#          2   9.07e-06     0.0202
#          3   1.85e-06      0.143
#          4   3.28e-09      0.154
#          5   1.55e-07      0.154
#          6   1.56e-08      0.154
#          7   1.37e-14      0.154
# done in 0.023 seconds
# Expected: 0.001 Actual: 0.001
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.19     |
# | EpisodesSoFar   | 22       |
# | EpLenMean       | 999      |
# | EpRewMean       | -45.6    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0777  |
# | meankl          | 0.000792 |
# | optimgain       | 0.00145  |
# | surrgain        | 0.00145  |
# | TimeElapsed     | 22.1     |
# | TimestepsSoFar  | 2.2e+04  |
# ------------------------------
# ********** Iteration 22 ************
# sampling
# done in 0.871 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00704          0
#          1   0.000287     0.0254
#          2   8.85e-05     0.0295
#          3   9.13e-06     0.0577
#          4   1.62e-09      0.246
#          5   1.35e-07      0.246
#          6   2.97e-09      0.246
#          7   8.66e-14      0.246
# done in 0.022 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.089 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.18     |
# | EpisodesSoFar   | 23       |
# | EpLenMean       | 999      |
# | EpRewMean       | -45.5    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.151   |
# | meankl          | 0.000914 |
# | optimgain       | 0.00267  |
# | surrgain        | 0.00267  |
# | TimeElapsed     | 23.1     |
# | TimestepsSoFar  | 2.3e+04  |
# ------------------------------
# ********** Iteration 23 ************
# sampling
# done in 0.857 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00242          0
#          1   0.000238     0.0133
#          2   1.22e-05     0.0763
#          3   4.38e-07     0.0767
#          4    1.1e-09     0.0948
#          5   1.78e-09     0.0948
#          6   5.05e-11     0.0949
# done in 0.019 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.095 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.18     |
# | EpisodesSoFar   | 24       |
# | EpLenMean       | 999      |
# | EpRewMean       | -45.4    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0473  |
# | meankl          | 0.000938 |
# | optimgain       | 0.00186  |
# | surrgain        | 0.00186  |
# | TimeElapsed     | 24.1     |
# | TimestepsSoFar  | 2.4e+04  |
# ------------------------------
# ********** Iteration 24 ************
# sampling
# done in 0.853 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0017          0
#          1   0.000154     0.0113
#          2    0.00016     0.0194
#          3   3.49e-07      0.104
#          4   1.58e-09       0.12
#          5   2.22e-10       0.12
#          6   2.58e-09       0.12
#          7   6.47e-18       0.12
# done in 0.024 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.092 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.17     |
# | EpisodesSoFar   | 25       |
# | EpLenMean       | 999      |
# | EpRewMean       | -45.2    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0297  |
# | meankl          | 0.000865 |
# | optimgain       | 0.00167  |
# | surrgain        | 0.00167  |
# | TimeElapsed     | 25.1     |
# | TimestepsSoFar  | 2.5e+04  |
# ------------------------------
# ********** Iteration 25 ************
# sampling
# done in 0.836 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00516          0
#          1   9.36e-05     0.0356
#          2   4.92e-05     0.0363
#          3   1.45e-06     0.0589
#          4   7.05e-10      0.127
#          5   2.75e-08      0.127
#          6   4.08e-08      0.127
#          7    2.5e-15      0.127
# done in 0.026 seconds
# Expected: 0.002 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.095 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.14     |
# | EpisodesSoFar   | 26       |
# | EpLenMean       | 999      |
# | EpRewMean       | -45      |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.0149   |
# | meankl          | 0.000972 |
# | optimgain       | 0.00251  |
# | surrgain        | 0.00251  |
# | TimeElapsed     | 26       |
# | TimestepsSoFar  | 2.6e+04  |
# ------------------------------
# ********** Iteration 26 ************
# sampling
# done in 0.867 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00484          0
#          1   0.000681     0.0192
#          2   0.000107     0.0266
#          3   3.74e-06     0.0836
#          4   1.35e-09      0.197
#          5   5.95e-10      0.197
#          6    1.6e-08      0.197
#          7   2.75e-15      0.197
# done in 0.022 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.13     |
# | EpisodesSoFar   | 27       |
# | EpLenMean       | 999      |
# | EpRewMean       | -44.9    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0199  |
# | meankl          | 0.00106  |
# | optimgain       | 0.00246  |
# | surrgain        | 0.00246  |
# | TimeElapsed     | 27       |
# | TimestepsSoFar  | 2.7e+04  |
# ------------------------------
# ********** Iteration 27 ************
# sampling
# done in 0.876 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00346          0
#          1   0.000511       0.03
#          2   0.000363     0.0336
#          3   9.89e-08     0.0961
#          4   5.88e-10        0.1
#          5   5.88e-09        0.1
#          6   2.34e-08        0.1
#          7   5.06e-14        0.1
# done in 0.026 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.1      |
# | EpisodesSoFar   | 28       |
# | EpLenMean       | 999      |
# | EpRewMean       | -44.7    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.0187   |
# | meankl          | 0.000988 |
# | optimgain       | 0.0024   |
# | surrgain        | 0.0024   |
# | TimeElapsed     | 28.1     |
# | TimestepsSoFar  | 2.8e+04  |
# ------------------------------
# ********** Iteration 28 ************
# sampling
# done in 0.861 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00482          0
#          1   0.000148     0.0123
#          2    1.1e-06     0.0146
#          3   2.32e-06     0.0266
#          4    6.1e-09     0.0769
#          5   3.31e-10     0.0769
#          6   8.32e-09      0.077
#          7   1.26e-14      0.077
# done in 0.022 seconds
# Expected: 0.001 Actual: 0.001
# Stepsize OK!
# vf
# done in 0.092 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.12     |
# | EpisodesSoFar   | 29       |
# | EpLenMean       | 999      |
# | EpRewMean       | -44.6    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0225  |
# | meankl          | 0.000848 |
# | optimgain       | 0.00148  |
# | surrgain        | 0.00148  |
# | TimeElapsed     | 29.1     |
# | TimestepsSoFar  | 2.9e+04  |
# ------------------------------
# ********** Iteration 29 ************
# sampling
# done in 0.850 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0105          0
#          1    0.00297     0.0314
#          2   0.000682     0.0486
#          3   1.81e-06      0.277
#          4   2.97e-08      0.309
#          5   4.32e-09      0.309
#          6    8.5e-08      0.309
#          7   1.53e-15      0.309
# done in 0.022 seconds
# Expected: 0.005 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.093 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.1      |
# | EpisodesSoFar   | 30       |
# | EpLenMean       | 999      |
# | EpRewMean       | -44.3    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.00211  |
# | meankl          | 0.000906 |
# | optimgain       | 0.00443  |
# | surrgain        | 0.00443  |
# | TimeElapsed     | 30       |
# | TimestepsSoFar  | 3e+04    |
# ------------------------------
# ********** Iteration 30 ************
# sampling
# done in 0.862 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00239          0
#          1   0.000436     0.0131
#          2   5.16e-06      0.018
#          3   1.07e-07     0.0599
#          4   4.32e-10     0.0709
#          5   8.16e-11     0.0709
# done in 0.016 seconds
# Expected: 0.001 Actual: 0.001
# Stepsize OK!
# vf
# done in 0.093 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.08     |
# | EpisodesSoFar   | 31       |
# | EpLenMean       | 999      |
# | EpRewMean       | -44.1    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.000738 |
# | meankl          | 0.000963 |
# | optimgain       | 0.00135  |
# | surrgain        | 0.00135  |
# | TimeElapsed     | 31       |
# | TimestepsSoFar  | 3.1e+04  |
# ------------------------------
# ********** Iteration 31 ************
# sampling
# done in 0.869 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00177          0
#          1   0.000462     0.0114
#          2   0.000186     0.0208
#          3   1.94e-06        0.1
#          4   9.53e-10      0.167
#          5   1.53e-11      0.167
# done in 0.018 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.099 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.06     |
# | EpisodesSoFar   | 32       |
# | EpLenMean       | 999      |
# | EpRewMean       | -43.9    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.001    |
# | meankl          | 0.000909 |
# | optimgain       | 0.00189  |
# | surrgain        | 0.00189  |
# | TimeElapsed     | 32.1     |
# | TimestepsSoFar  | 3.2e+04  |
# ------------------------------
# ********** Iteration 32 ************
# sampling
# done in 0.881 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00122          0
#          1   0.000403    0.00789
#          2   0.000224     0.0195
#          3   2.54e-05      0.105
#          4    4.8e-09      0.443
#          5   2.77e-10      0.443
#          6   4.24e-09      0.443
#          7   4.64e-14      0.443
# done in 0.021 seconds
# Expected: 0.003 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.099 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.06     |
# | EpisodesSoFar   | 33       |
# | EpLenMean       | 999      |
# | EpRewMean       | -43.7    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.0472   |
# | meankl          | 0.00059  |
# | optimgain       | 0.00241  |
# | surrgain        | 0.00241  |
# | TimeElapsed     | 33.1     |
# | TimestepsSoFar  | 3.3e+04  |
# ------------------------------
# ********** Iteration 33 ************
# sampling
# done in 0.856 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0253          0
#          1     0.0065     0.0468
#          2   1.95e-05     0.0643
#          3   8.84e-07     0.0669
#          4   2.66e-09      0.102
#          5   2.45e-10      0.102
#          6   8.92e-09      0.102
#          7   5.13e-14      0.102
# done in 0.027 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.091 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.03     |
# | EpisodesSoFar   | 34       |
# | EpLenMean       | 999      |
# | EpRewMean       | -43.5    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0166  |
# | meankl          | 0.00102  |
# | optimgain       | 0.0043   |
# | surrgain        | 0.0043   |
# | TimeElapsed     | 34.1     |
# | TimestepsSoFar  | 3.4e+04  |
# ------------------------------
# ********** Iteration 34 ************
# sampling
# done in 0.859 seconds
# computegrad
# done in 0.005 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0204          0
#          1     0.0011     0.0258
#          2    0.00127     0.0519
#          3   2.58e-05      0.185
#          4   2.55e-08      0.507
#          5   1.41e-09      0.507
#          6   3.03e-08      0.507
#          7   3.13e-14      0.507
# done in 0.025 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.098 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.03     |
# | EpisodesSoFar   | 35       |
# | EpLenMean       | 999      |
# | EpRewMean       | -43.4    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.0168   |
# | meankl          | 0.000665 |
# | optimgain       | 0.00472  |
# | surrgain        | 0.00472  |
# | TimeElapsed     | 35.1     |
# | TimestepsSoFar  | 3.5e+04  |
# ------------------------------
# ********** Iteration 35 ************
# sampling
# done in 0.877 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00206          0
#          1   0.000512     0.0162
#          2   3.81e-06     0.0202
#          3   1.61e-08     0.0286
#          4    1.9e-08     0.0314
#          5   5.22e-11     0.0314
# done in 0.018 seconds
# Expected: 0.001 Actual: 0.001
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 1.01     |
# | EpisodesSoFar   | 36       |
# | EpLenMean       | 999      |
# | EpRewMean       | -43.2    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.00123  |
# | meankl          | 0.00101  |
# | optimgain       | 0.00139  |
# | surrgain        | 0.00139  |
# | TimeElapsed     | 36.1     |
# | TimestepsSoFar  | 3.6e+04  |
# ------------------------------
# ********** Iteration 36 ************
# sampling
# done in 0.864 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00484          0
#          1     0.0017     0.0234
#          2   0.000129     0.0325
#          3   3.48e-08     0.0579
#          4   1.28e-09     0.0603
#          5   2.02e-10     0.0603
#          6   7.01e-09     0.0604
#          7   2.35e-13     0.0604
# done in 0.026 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.096 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.98     |
# | EpisodesSoFar   | 37       |
# | EpLenMean       | 999      |
# | EpRewMean       | -43      |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.00521 |
# | meankl          | 0.00102  |
# | optimgain       | 0.00224  |
# | surrgain        | 0.00224  |
# | TimeElapsed     | 37.1     |
# | TimestepsSoFar  | 3.7e+04  |
# ------------------------------
# ********** Iteration 37 ************
# sampling
# done in 0.887 seconds
# computegrad
# done in 0.005 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00879          0
#          1   0.000815     0.0476
#          2   0.000702     0.0513
#          3   8.21e-07      0.231
#          4   4.72e-09       0.25
#          5   3.06e-10       0.25
#          6   1.33e-08       0.25
#          7   5.04e-15       0.25
# done in 0.025 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.958    |
# | EpisodesSoFar   | 38       |
# | EpLenMean       | 999      |
# | EpRewMean       | -42.8    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.00879  |
# | meankl          | 0.00102  |
# | optimgain       | 0.00435  |
# | surrgain        | 0.00435  |
# | TimeElapsed     | 38.1     |
# | TimestepsSoFar  | 3.8e+04  |
# ------------------------------
# ********** Iteration 38 ************
# sampling
# done in 0.833 seconds
# computegrad
# done in 0.005 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00931          0
#          1    0.00269      0.022
#          2    0.00016      0.037
#          3   2.31e-08     0.0632
#          4   2.16e-08     0.0645
#          5   6.75e-11     0.0646
# done in 0.018 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.091 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.934    |
# | EpisodesSoFar   | 39       |
# | EpLenMean       | 999      |
# | EpRewMean       | -42.6    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.00628 |
# | meankl          | 0.00102  |
# | optimgain       | 0.00266  |
# | surrgain        | 0.00266  |
# | TimeElapsed     | 39.1     |
# | TimestepsSoFar  | 3.9e+04  |
# ------------------------------
# ********** Iteration 39 ************
# sampling
# done in 0.850 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00433          0
#          1   0.000368     0.0111
#          2    8.4e-05     0.0178
#          3   1.49e-06       0.16
#          4   2.69e-08      0.211
#          5   3.37e-10      0.211
#          6   1.08e-08      0.211
#          7   1.28e-16      0.211
# done in 0.028 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.097 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.923    |
# | EpisodesSoFar   | 41       |
# | EpLenMean       | 999      |
# | EpRewMean       | -42      |
# | EpThisIter      | 2        |
# | ev_tdlam_before | 0.00798  |
# | meankl          | 0.00109  |
# | optimgain       | 0.00244  |
# | surrgain        | 0.00244  |
# | TimeElapsed     | 40.1     |
# | TimestepsSoFar  | 4.1e+04  |
# ------------------------------
# ********** Iteration 40 ************
# sampling
# done in 0.885 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00798          0
#          1   0.000581     0.0475
#          2    0.00532     0.0682
#          3   3.35e-07      0.287
#          4   2.97e-10      0.293
#          5    1.3e-10      0.293
#          6   2.21e-10      0.293
#          7   1.89e-15      0.293
# done in 0.022 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.091 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.904    |
# | EpisodesSoFar   | 42       |
# | EpLenMean       | 999      |
# | EpRewMean       | -41.5    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.0042   |
# | meankl          | 0.000912 |
# | optimgain       | 0.00451  |
# | surrgain        | 0.00451  |
# | TimeElapsed     | 41.1     |
# | TimestepsSoFar  | 4.2e+04  |
# ------------------------------
# ********** Iteration 41 ************
# sampling
# done in 0.856 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0579          0
#          1    0.00293     0.0349
#          2   0.000692     0.0531
#          3   2.82e-06      0.158
#          4   1.64e-06      0.223
#          5   1.26e-09      0.223
#          6   4.78e-08      0.223
#          7    8.1e-14      0.223
# done in 0.023 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.100 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.892    |
# | EpisodesSoFar   | 43       |
# | EpLenMean       | 999      |
# | EpRewMean       | -41      |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.00984  |
# | meankl          | 0.0011   |
# | optimgain       | 0.00532  |
# | surrgain        | 0.00532  |
# | TimeElapsed     | 42.1     |
# | TimestepsSoFar  | 4.3e+04  |
# ------------------------------
# ********** Iteration 42 ************
# sampling
# done in 0.874 seconds
# computegrad
# done in 0.005 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0106          0
#          1    0.00453      0.028
#          2   2.85e-05     0.0431
#          3   7.06e-07      0.068
#          4   9.75e-08      0.108
#          5   2.91e-10      0.108
#          6   4.96e-10      0.108
#          7   2.36e-15      0.108
# done in 0.028 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.099 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.864    |
# | EpisodesSoFar   | 44       |
# | EpLenMean       | 999      |
# | EpRewMean       | -40.5    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.00176  |
# | meankl          | 0.000983 |
# | optimgain       | 0.00278  |
# | surrgain        | 0.00278  |
# | TimeElapsed     | 43.2     |
# | TimestepsSoFar  | 4.4e+04  |
# ------------------------------
# ********** Iteration 43 ************
# sampling
# done in 0.899 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00821          0
#          1    0.00482     0.0317
#          2   0.000259     0.0448
#          3   1.45e-05     0.0597
#          4   1.68e-08      0.283
#          5   1.87e-07      0.283
#          6   2.28e-09      0.283
#          7   3.65e-12      0.283
# done in 0.026 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.839    |
# | EpisodesSoFar   | 45       |
# | EpLenMean       | 999      |
# | EpRewMean       | -40.1    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0375  |
# | meankl          | 0.000829 |
# | optimgain       | 0.00313  |
# | surrgain        | 0.00313  |
# | TimeElapsed     | 44.2     |
# | TimestepsSoFar  | 4.5e+04  |
# ------------------------------
# ********** Iteration 44 ************
# sampling
# done in 0.878 seconds
# computegrad
# done in 0.005 seconds
# cg
#       iter residual norm  soln norm
#          0      0.016          0
#          1    0.00826     0.0278
#          2    0.00137     0.0606
#          3   3.98e-07      0.157
#          4   4.29e-08      0.166
#          5   8.94e-10      0.166
#          6   3.01e-08      0.166
#          7   8.88e-13      0.166
# done in 0.029 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.098 seconds
# -------------------------------
# | entloss         | 0         |
# | entropy         | 0.821     |
# | EpisodesSoFar   | 46        |
# | EpLenMean       | 999       |
# | EpRewMean       | -39.7     |
# | EpThisIter      | 1         |
# | ev_tdlam_before | -0.000499 |
# | meankl          | 0.00101   |
# | optimgain       | 0.00461   |
# | surrgain        | 0.00461   |
# | TimeElapsed     | 45.2      |
# | TimestepsSoFar  | 4.6e+04   |
# -------------------------------
# ********** Iteration 45 ************
# sampling
# done in 0.897 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00658          0
#          1    0.00071     0.0105
#          2   3.43e-05      0.019
#          3   3.88e-06     0.0539
#          4   2.88e-06      0.189
#          5   1.98e-11      0.189
# done in 0.019 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.098 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.804    |
# | EpisodesSoFar   | 47       |
# | EpLenMean       | 999      |
# | EpRewMean       | -39.3    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.00697  |
# | meankl          | 0.000886 |
# | optimgain       | 0.00193  |
# | surrgain        | 0.00193  |
# | TimeElapsed     | 46.3     |
# | TimestepsSoFar  | 4.7e+04  |
# ------------------------------
# ********** Iteration 46 ************
# sampling
# done in 0.893 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00527          0
#          1   0.000222     0.0358
#          2   1.33e-05     0.0362
#          3   1.26e-07     0.0419
#          4   7.25e-10     0.0559
#          5   1.17e-10     0.0559
#          6   1.69e-10     0.0559
#          7    7.5e-15     0.0559
# done in 0.025 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.093 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.773    |
# | EpisodesSoFar   | 48       |
# | EpLenMean       | 999      |
# | EpRewMean       | -38.8    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0148  |
# | meankl          | 0.00101  |
# | optimgain       | 0.00227  |
# | surrgain        | 0.00227  |
# | TimeElapsed     | 47.3     |
# | TimestepsSoFar  | 4.8e+04  |
# ------------------------------
# ********** Iteration 47 ************
# sampling
# done in 0.846 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00767          0
#          1   0.000503     0.0439
#          2    0.00019     0.0448
#          3   2.22e-07      0.188
#          4   3.09e-09      0.195
#          5   2.61e-10      0.195
#          6   5.79e-12      0.195
# done in 0.019 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.086 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.748    |
# | EpisodesSoFar   | 49       |
# | EpLenMean       | 999      |
# | EpRewMean       | -38.3    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.000842 |
# | meankl          | 0.000956 |
# | optimgain       | 0.0034   |
# | surrgain        | 0.0034   |
# | TimeElapsed     | 48.3     |
# | TimestepsSoFar  | 4.9e+04  |
# ------------------------------
# ********** Iteration 48 ************
# sampling
# done in 0.782 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0121          0
#          1   0.000529     0.0113
#          2   4.41e-05     0.0182
#          3   5.57e-07      0.096
#          4   5.38e-06      0.125
#          5   1.32e-11      0.125
# done in 0.014 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 0.085 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.735    |
# | EpisodesSoFar   | 50       |
# | EpLenMean       | 999      |
# | EpRewMean       | -37.8    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.00165 |
# | meankl          | 0.000872 |
# | optimgain       | 0.00196  |
# | surrgain        | 0.00196  |
# | TimeElapsed     | 49.2     |
# | TimestepsSoFar  | 5e+04    |
# ------------------------------
# ********** Iteration 49 ************
# sampling
# done in 0.807 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0601          0
#          1      0.018     0.0309
#          2   1.07e-06     0.0742
#          3   2.02e-08     0.0744
#          4   5.82e-07     0.0758
#          5   3.94e-11     0.0758
# done in 0.016 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.091 seconds
# ------------------------------
# | entloss         | 0        |
# | entropy         | 0.708    |
# | EpisodesSoFar   | 51       |
# | EpLenMean       | 999      |
# | EpRewMean       | -37.2    |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0141  |
# | meankl          | 0.00103  |
# | optimgain       | 0.00535  |
# | surrgain        | 0.00535  |
# | TimeElapsed     | 50.1     |
# | TimestepsSoFar  | 5.09e+04 |
# ------------------------------
# ********** Iteration 50 ************
# sampling
# done in 0.855 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0769          0
#          1    0.00364     0.0253
#          2   9.31e-06     0.0424
#          3   1.44e-07     0.0482
#          4   3.19e-06     0.0598
#          5   4.17e-10     0.0601
#          6   1.28e-08     0.0602
#          7   1.84e-13     0.0602
# done in 0.021 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.091 seconds
# -------------------------------
# | entloss         | 0         |
# | entropy         | 0.691     |
# | EpisodesSoFar   | 52        |
# | EpLenMean       | 999       |
# | EpRewMean       | -36.7     |
# | EpThisIter      | 1         |
# ...
# cg
#       iter residual norm  soln norm
#          0         15          0
#          1      0.108   0.000103
#          2    0.00602    0.00649
#          3       13.2     0.0349
#          4   6.73e-05     0.0402
#          5    0.00103     0.0431
#          6   9.09e-08     0.0431
#          7   1.37e-05     0.0431
#          8    0.00257     0.0431
#          9    9.5e-09     0.0464
#         10   8.23e-07     0.0464
# done in 0.037 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.097 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.09    |
# | EpisodesSoFar   | 282      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0298  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.619   |
# | meankl          | 0.00106  |
# | optimgain       | 0.00336  |
# | surrgain        | 0.00336  |
# | TimeElapsed     | 280      |
# | TimestepsSoFar  | 2.82e+05 |
# ------------------------------
# ********** Iteration 276 ************
# sampling
# done in 0.843 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0      0.044          0
#          1      0.164   2.47e-05
#          2    0.00149     0.0145
#          3    0.00053     0.0281
#          4   0.000278     0.0281
#          5   1.66e-05      0.091
#          6    0.00287      0.091
#          7   4.59e-05      0.385
#          8     0.0284      0.385
#          9   1.11e-11      0.386
# done in 0.025 seconds
# Expected: 0.003 Actual: -0.006
# violated KL constraint. shrinking step.
# Expected: 0.003 Actual: 0.000
# violated KL constraint. shrinking step.
# Expected: 0.003 Actual: 0.001
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.09    |
# | EpisodesSoFar   | 283      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0288  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.302   |
# | meankl          | 0.00146  |
# | optimgain       | 0.000697 |
# | surrgain        | 0.000697 |
# | TimeElapsed     | 281      |
# | TimestepsSoFar  | 2.83e+05 |
# ------------------------------
# ********** Iteration 277 ************
# sampling
# done in 0.876 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0         39          0
#          1     0.0119   0.000158
#          2    0.00155     0.0442
#          3      0.601     0.0444
#          4   3.04e-05       0.05
#          5       4.46     0.0634
#          6   8.95e-09      0.103
#          7    6.2e-05      0.103
#          8   3.78e-07      0.103
#          9   0.000103      0.103
#         10   6.18e-10      0.103
# done in 0.029 seconds
# Expected: 0.004 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.12    |
# | EpisodesSoFar   | 284      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0279  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.00603  |
# | meankl          | 0.000893 |
# | optimgain       | 0.00271  |
# | surrgain        | 0.00271  |
# | TimeElapsed     | 282      |
# | TimestepsSoFar  | 2.84e+05 |
# ------------------------------
# ********** Iteration 278 ************
# sampling
# done in 0.901 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0        339          0
#          1     0.0143   0.000455
#          2    0.00746    0.00727
#          3       2.84    0.00792
#          4   8.47e-06      0.038
#          5      0.438     0.0386
#          6   8.77e-06     0.0428
#          7       3.13      0.117
#          8   2.77e-06      0.176
#          9   0.000106      0.176
#         10   5.24e-10      0.176
# done in 0.033 seconds
# Expected: 0.005 Actual: 0.012
# violated KL constraint. shrinking step.
# Expected: 0.005 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.097 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.13    |
# | EpisodesSoFar   | 285      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.027   |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.324   |
# | meankl          | 0.000872 |
# | optimgain       | 0.0043   |
# | surrgain        | 0.0043   |
# | TimeElapsed     | 283      |
# | TimestepsSoFar  | 2.85e+05 |
# ------------------------------
# ********** Iteration 279 ************
# sampling
# done in 0.813 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0        128          0
#          1     0.0143   0.000269
#          2    0.00173     0.0334
#          3     0.0575     0.0334
#          4   4.77e-05     0.0425
#          5       4.66     0.0492
#          6    5.8e-08      0.119
#          7   4.43e-05      0.119
#          8   1.34e-07      0.122
#          9   8.86e-05      0.122
#         10   1.58e-09      0.122
# done in 0.034 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.092 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.14    |
# | EpisodesSoFar   | 287      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0254  |
# | EpThisIter      | 2        |
# | ev_tdlam_before | -0.0035  |
# | meankl          | 0.000968 |
# | optimgain       | 0.00386  |
# | surrgain        | 0.00386  |
# | TimeElapsed     | 284      |
# | TimestepsSoFar  | 2.87e+05 |
# ------------------------------
# ********** Iteration 280 ************
# sampling
# done in 0.861 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0        106          0
#          1     0.0192   0.000227
#          2    0.00151    0.00759
#          3       3.37    0.00845
#          4   0.000345      0.027
#          5     0.0657      0.077
#          6   1.13e-05     0.0771
#          7    0.00427      0.289
#          8   0.000183      0.289
#          9   8.63e-10      0.291
#         10   7.96e-10      0.291
# done in 0.032 seconds
# Expected: 0.004 Actual: -0.029
# violated KL constraint. shrinking step.
# Expected: 0.004 Actual: -0.005
# violated KL constraint. shrinking step.
# Expected: 0.004 Actual: -0.001
# surrogate didn't improve. shrinking step.
# Expected: 0.004 Actual: 0.000
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.14    |
# | EpisodesSoFar   | 288      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0246  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.161    |
# | meankl          | 1.87e-05 |
# | optimgain       | 5.06e-05 |
# | surrgain        | 5.06e-05 |
# | TimeElapsed     | 285      |
# | TimestepsSoFar  | 2.88e+05 |
# ------------------------------
# ********** Iteration 281 ************
# sampling
# done in 0.861 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0      0.437          0
#          1      0.821   4.21e-05
#          2    0.00146    0.00878
#          3      0.843     0.0509
#          4   9.88e-05     0.0514
#          5   9.64e-05     0.0546
#          6   0.000596     0.0546
#          7     0.0228      0.228
#          8     0.0315      0.304
#          9   2.98e-08      0.304
#         10    0.00257      0.305
# done in 0.032 seconds
# Expected: 0.004 Actual: 0.006
# violated KL constraint. shrinking step.
# Expected: 0.004 Actual: 0.002
# violated KL constraint. shrinking step.
# Expected: 0.004 Actual: 0.001
# Stepsize OK!
# vf
# done in 0.095 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.14    |
# | EpisodesSoFar   | 289      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0239  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.793   |
# | meankl          | 0.000447 |
# | optimgain       | 0.00112  |
# | surrgain        | 0.00112  |
# | TimeElapsed     | 286      |
# | TimestepsSoFar  | 2.89e+05 |
# ------------------------------
# ********** Iteration 282 ************
# sampling
# done in 0.860 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0      0.212          0
#          1     0.0344    1.2e-05
#          2   0.000479     0.0878
#          3       1.06     0.0879
#          4   2.16e-06     0.0966
#          5    0.00431     0.0966
#          6   1.32e-08      0.125
#          7    6.9e-11      0.125
# done in 0.023 seconds
# Expected: 0.006 Actual: 0.006
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.17    |
# | EpisodesSoFar   | 290      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0232  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.00641  |
# | meankl          | 0.00108  |
# | optimgain       | 0.00559  |
# | surrgain        | 0.00559  |
# | TimeElapsed     | 287      |
# | TimestepsSoFar  | 2.9e+05  |
# ------------------------------
# ********** Iteration 283 ************
# sampling
# done in 0.865 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0         66          0
#          1    0.00583   0.000177
#          2   4.28e-05     0.0383
#          3   6.27e-05     0.0383
#          4   1.09e-05     0.0392
#          5      0.748      0.111
#          6   3.37e-09      0.117
#          7   9.21e-06      0.117
#          8   8.36e-11      0.118
# done in 0.026 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.092 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.2     |
# | EpisodesSoFar   | 291      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0223  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.00797  |
# | meankl          | 0.00142  |
# | optimgain       | 0.00349  |
# | surrgain        | 0.00349  |
# | TimeElapsed     | 288      |
# | TimestepsSoFar  | 2.91e+05 |
# ------------------------------
# ********** Iteration 284 ************
# sampling
# done in 0.874 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0        114          0
#          1     0.0195   0.000211
#          2    0.00908     0.0481
#          3       1.93     0.0484
#          4   3.73e-05      0.064
#          5        2.8     0.0657
#          6   3.74e-09     0.0873
#          7   5.27e-07     0.0873
#          8   6.31e-07     0.0874
#          9    0.00151     0.0875
#         10   4.29e-09     0.0876
# done in 0.035 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.101 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.23    |
# | EpisodesSoFar   | 292      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0217  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.0636   |
# | meankl          | 0.00108  |
# | optimgain       | 0.00467  |
# | surrgain        | 0.00467  |
# | TimeElapsed     | 289      |
# | TimestepsSoFar  | 2.92e+05 |
# ------------------------------
# ********** Iteration 285 ************
# sampling
# done in 0.847 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0         95          0
#          1     0.0648   0.000179
#          2    0.00557     0.0197
#          3       2.24     0.0199
#          4   0.000111     0.0456
#          5       5.62     0.0642
#          6    1.9e-06     0.0741
#          7     0.0131      0.156
#          8   1.22e-05      0.156
#          9   1.61e-07      0.156
#         10   8.97e-11      0.156
# done in 0.034 seconds
# Expected: 0.004 Actual: 0.007
# violated KL constraint. shrinking step.
# Expected: 0.004 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.091 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.23    |
# | EpisodesSoFar   | 293      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.021   |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.0924   |
# | meankl          | 0.000593 |
# | optimgain       | 0.00301  |
# | surrgain        | 0.00301  |
# | TimeElapsed     | 290      |
# | TimestepsSoFar  | 2.93e+05 |
# ------------------------------
# ********** Iteration 286 ************
# sampling
# done in 0.858 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0       20.6          0
#          1     0.0144   8.12e-05
#          2   0.000334     0.0601
#          3      0.125     0.0601
#          4   0.000242     0.0606
#          5      0.453      0.105
#          6   6.13e-07      0.106
#          7     0.0802      0.129
#          8   1.41e-07       0.13
#          9   6.97e-07       0.13
#         10   7.55e-12       0.13
# done in 0.035 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.094 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.26    |
# | EpisodesSoFar   | 294      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0204  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.0958   |
# | meankl          | 0.000968 |
# | optimgain       | 0.004    |
# | surrgain        | 0.004    |
# | TimeElapsed     | 291      |
# | TimestepsSoFar  | 2.94e+05 |
# ------------------------------
# ********** Iteration 287 ************
# sampling
# done in 0.854 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0       54.3          0
#          1     0.0243   0.000118
#          2     0.0233      0.013
#          3       10.1      0.058
#          4   5.24e-05     0.0595
#          5    0.00583     0.0643
#          6   1.16e-06     0.0643
#          7   3.32e-06      0.116
#          8   1.29e-07      0.116
#          9   5.72e-11      0.116
# done in 0.030 seconds
# Expected: 0.004 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.091 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.29    |
# | EpisodesSoFar   | 295      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0198  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | 0.0732   |
# | meankl          | 0.0011   |
# | optimgain       | 0.00304  |
# | surrgain        | 0.00304  |
# | TimeElapsed     | 292      |
# | TimestepsSoFar  | 2.95e+05 |
# ------------------------------
# ********** Iteration 288 ************
# sampling
# done in 0.851 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0       2.94          0
#          1    0.00994    2.7e-05
#          2     0.0416     0.0162
#          3       40.5     0.0387
#          4   0.000263     0.0487
#          5     0.0111     0.0974
#          6   0.000418     0.0974
#          7   0.000689      0.553
#          8    0.00372      0.553
#          9    2.9e-08      0.554
#         10    7.5e-05      0.554
# done in 0.034 seconds
# Expected: 0.005 Actual: -0.076
# violated KL constraint. shrinking step.
# Expected: 0.005 Actual: -0.003
# violated KL constraint. shrinking step.
# Expected: 0.005 Actual: 0.001
# violated KL constraint. shrinking step.
# Expected: 0.005 Actual: 0.000
# Stepsize OK!
# vf
# done in 0.092 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.29    |
# | EpisodesSoFar   | 296      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0191  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -1.45    |
# | meankl          | 0.000151 |
# | optimgain       | 0.000474 |
# | surrgain        | 0.000474 |
# | TimeElapsed     | 293      |
# | TimestepsSoFar  | 2.96e+05 |
# ------------------------------
# ********** Iteration 289 ************
# sampling
# done in 0.844 seconds
# computegrad
# done in 0.004 seconds
# cg
#       iter residual norm  soln norm
#          0       33.8          0
#          1      0.116   9.19e-05
#          2    0.00765      0.004
#          3       39.4     0.0409
#          4   0.000302     0.0498
#          5     0.0332     0.0536
#          6   4.28e-07     0.0536
#          7     0.0656     0.0609
#          8   2.98e-05     0.0618
#          9   4.71e-06      0.062
#         10   5.44e-08      0.062
# done in 0.035 seconds
# Expected: 0.004 Actual: 0.003
# Stepsize OK!
# vf
# done in 0.100 seconds
# ------------------------------
# | entloss         | -0       |
# | entropy         | -3.31    |
# | EpisodesSoFar   | 297      |
# | EpLenMean       | 999      |
# | EpRewMean       | -0.0186  |
# | EpThisIter      | 1        |
# | ev_tdlam_before | -0.0262  |
# | meankl          | 0.000932 |
# | optimgain       | 0.00336  |
# | surrgain        | 0.00336  |
# | TimeElapsed     | 294      |
# | TimestepsSoFar  | 2.97e+05 |
# ------------------------------
# ********** Iteration 290 ************
# sampling

# %%
python -m baselines.run --alg=trpo_mpi --env='MountainCarContinuous-v0' --num_timesteps=0 --load_path=~/models/mountaincar_trpo_te5 --play

# %%
from baselines.common import plot_util as pu
results = pu.load_results('~/logs/cartpole-ppo')
# Out:
# skipping progress file in  /home/hchonglondon/logs/cartpole-ppo empty data
# /home/hchonglondon/.local/lib/python3.5/site-packages/pandas/core/computation/check.py:19: UserWarning: The installed version of numexpr 2.5 is not supported in pandas and will be not be used
# The minimum supported version is 2.6.1
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# /home/hchonglondon/baselines/baselines/bench/monitor.py:163: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
import matplotlib.pyplot as plt
import numpy as np
r = results[0]
plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-06b1d904d380> in <module>()
#       2 import numpy as np
#       3 r = results[0]
# ----> 4 plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
#
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3145 @_autogen_docstring(Axes.plot)
#    3146 def plot(*args, **kwargs):
# -> 3147     ax = gca()
#    3148     # allow callers to override the hold state by passing hold=True|False
#    3149     washold = ax.ishold()
#
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in gca(**kwargs)
#     926     matplotlib.figure.Figure.gca : The figure's gca method.
#     927     """
# --> 928     return gcf().gca(**kwargs)
#     929
#     930 # More ways of creating axes:
#
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in gcf()
#     576         return figManager.canvas.figure
#     577     else:
# --> 578         return figure()
#     579
#     580
#
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, **kwargs)
#     525                                         frameon=frameon,
#     526                                         FigureClass=FigureClass,
# --> 527                                         **kwargs)
#     528
#     529         if figLabel:
#
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/matplotlib/backends/backend_qt4agg.py in new_figure_manager(num, *args, **kwargs)
#      44     FigureClass = kwargs.pop('FigureClass', Figure)
#      45     thisFig = FigureClass(*args, **kwargs)
# ---> 46     return new_figure_manager_given_figure(num, thisFig)
#      47
#      48
#
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/matplotlib/backends/backend_qt4agg.py in new_figure_manager_given_figure(num, figure)
#      51     Create a new figure manager instance for the given figure.
#      52     """
# ---> 53     canvas = FigureCanvasQTAgg(figure)
#      54     return FigureManagerQT(canvas, num)
#      55
#
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/matplotlib/backends/backend_qt4agg.py in __init__(self, figure)
#      74         if DEBUG:
#      75             print('FigureCanvasQtAgg: ', figure)
# ---> 76         FigureCanvasQT.__init__(self, figure)
#      77         FigureCanvasQTAggBase.__init__(self, figure)
#      78         FigureCanvasAgg.__init__(self, figure)
#
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/matplotlib/backends/backend_qt4.py in __init__(self, figure)
#      66         if DEBUG:
#      67             print('FigureCanvasQt qt4: ', figure)
# ---> 68         _create_qApp()
#      69
#      70         # Note different super-calling style to backend_qt5
#
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/matplotlib/backends/backend_qt5.py in _create_qApp()
#     136                 display = os.environ.get('DISPLAY')
#     137                 if display is None or not re.search(':\d', display):
# --> 138                     raise RuntimeError('Invalid DISPLAY variable')
#     139
#     140             qApp = QtWidgets.QApplication([str(" ")])
#
# RuntimeError: Invalid DISPLAY variable
